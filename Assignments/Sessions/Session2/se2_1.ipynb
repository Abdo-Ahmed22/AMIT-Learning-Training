# %%
class student:
    count=0
    def __init__(self,name,age,course):
        self.name = name
        self.age = age
        self.courses = course
        student.count+=1
        
    @classmethod
    def total(cls):
        print(cls.count)

# %%
s1=student('abdo',23,3)
s2=student('ahmed',23,3)

# %%
student.total()
# Out:
# 2
